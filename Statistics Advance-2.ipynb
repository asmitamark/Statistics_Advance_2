# %%
# Question1: Define the z-statistic and explain its relationship to the standard normal distribution.
# How is the z-statistic used in hypothesis testing?

# %% [markdown]
# The z-statistic is a standardized score that indicates how many standard deviations a data point is from the mean of a distribution. It is calculated using the formula:
#
# 𝑧
# =
# (
# 𝑋
# −
# 𝜇
# )/
# 𝜎
#
#
# ​
#
# where:
#
# 𝑋
# X is the value of the observation,
# 𝜇
# μ is the mean of the population,
# 𝜎
# σ is the standard deviation of the population.
# Relationship to the Standard Normal Distribution
# The z-statistic follows the standard normal distribution, which is a normal distribution with a mean of 0 and a standard deviation of 1. This means that any normally distributed variable can be transformed into a z-score, allowing for comparison across different datasets or populations.
#
# Use in Hypothesis Testing
# In hypothesis testing, the z-statistic is used to determine how far the sample mean (or other statistic) is from the null hypothesis. Here’s how it typically works:
#
# Formulate Hypotheses: Establish a null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) and an alternative hypothesis (
# 𝐻
# 1
# H
# 1
# ​
#  ).
#
# Calculate the Z-statistic: For a given sample, calculate the z-statistic based on the sample mean, population mean, and standard deviation.
#
# Determine the Critical Value: Using the standard normal distribution, find the critical z-value(s) that correspond to the significance level (e.g.,
# 𝛼
# =
# 0.05
# α=0.05).
#
# Make a Decision: Compare the calculated z-statistic to the critical z-value:
#
# If the z-statistic falls into the rejection region (beyond the critical value), reject the null hypothesis.
# If the z-statistic falls within the acceptance region, do not reject the null hypothesis.
# This process allows researchers to assess whether their sample provides sufficient evidence to support or refute the null hypothesis in the context of the population from which it was drawn.

# %%
# Question2 : What is a p-value, and how is it used in hypothesis testing? What does it mean if the
# p-value isvery small (e.g., 0.01)?

# %% [markdown]
# A p-value is a statistical measure that helps determine the significance of your results in hypothesis testing. It quantifies the probability of obtaining an observed statistic (or one more extreme) under the assumption that the null hypothesis (
# 𝐻
# 0
#
# ​
#  ) is true.
#
# How p-values are Used in Hypothesis Testing
# Set Hypotheses: Formulate the null hypothesis (
# 𝐻
# 0
#
# ​
#  ) and the alternative hypothesis (
# 𝐻
# 1
#
# ​
#  ).
#
# Conduct the Test: Perform the statistical test and calculate the test statistic (e.g., z-statistic, t-statistic).
#
# Calculate the p-value: Determine the p-value associated with the observed test statistic. This can be done using statistical software or z/t distribution tables.
#
# Compare with Significance Level: Compare the p-value to a predetermined significance level (usually
# 𝛼
# =
# 0.05
# α=0.05):
#
# If
# p-value
# ≤
# 𝛼
# p-value≤α: Reject the null hypothesis.
# If
# p-value
# >
# 𝛼
# p-value>α: Do not reject the null hypothesis.
# Interpretation of a Small p-value
# If the p-value is very small (e.g., 0.01), it indicates strong evidence against the null hypothesis. Specifically:
#
# A p-value of 0.01 means there is only a 1% probability of observing the test statistic (or one more extreme) if the null hypothesis is true.
# This small p-value suggests that the observed effect is unlikely to have occurred by random chance alone, leading researchers to conclude that the effect is statistically significant.
# Consequently, researchers would typically reject the null hypothesis in favor of the alternative hypothesis (
# 𝐻
# 1
#
# ​
#  ), suggesting that there is evidence for the effect or relationship being tested.
# In summary, a small p-value indicates strong evidence against
# 𝐻
# 0
#
# ​
#   and suggests that the results are statistically significant.

# %%
# Question3: Compare and contrast the binomial and Bernoulli distributions.

# %% [markdown]
# The Bernoulli and binomial distributions are closely related but serve different purposes in probability and statistics. Here’s a comparison of the two:
#
# Bernoulli Distribution
# Definition: The Bernoulli distribution models a single trial with two possible outcomes: success (with probability
# p) and failure (with probability
# 1−p).
#
# Parameters: It has one parameter,
#
# p, which represents the probability of success.
#
# Support: The outcomes can be represented as 1 (success) and 0 (failure).
#
# Mean and Variance:
#
# Mean: E[X]=p
# Variance: Var(X)=p(1−p)
# Applications: Used in situations where you want to model a single yes/no or success/failure scenario (e.g., flipping a coin once, passing a test).
#
# Binomial Distribution
# Definition: The binomial distribution extends the Bernoulli distribution to multiple independent trials, counting the number of successes in
#
# n trials.
#
# Parameters: It has two parameters:
#
# n (the number of trials) and
#
# p (the probability of success in each trial).
#
# Support: The outcomes range from 0 to
#
# n (the total number of successes).
#
# Mean and Variance:
#
# Mean: E[X]=np
# Variance: Var(X)=np(1−p)
# Applications: Used to model scenarios with multiple independent trials (e.g., flipping a coin
#
# n times, determining how many times a certain event occurs in a fixed number of trials).
#
# Key Comparisons
# Single vs. Multiple Trials: The Bernoulli distribution is for one trial, while the binomial distribution is for
#
# n trials.
#
# Outcomes: The Bernoulli distribution has two outcomes (0 and 1), whereas the binomial distribution can yield outcomes from 0 to
#
# n.
#
# Probability Structure: In the Bernoulli case, the distribution is defined directly by the probability of success; in the binomial case, it is defined by the number of trials and the success probability per trial.

# %%
# Question 4: Under what conditions is the binomial distribution used, and how does it relate to the 
# Bernoulli distribution?

# %% [markdown]
# The binomial distribution is used under specific conditions that characterize the scenarios it models. These conditions are:
#
# Conditions for Using the Binomial Distribution
# Fixed Number of Trials: The number of trials
#
# n is predetermined and constant.
#
# Two Possible Outcomes: Each trial has only two possible outcomes: success (usually denoted as 1) and failure (denoted as 0).
#
# Constant Probability of Success: The probability of success
#
# p remains constant across all trials. The probability of failure is then
#
# 1−p.
#
# Independent Trials: The trials are independent of one another, meaning the outcome of one trial does not affect the outcomes of others.
#
# Relationship to the Bernoulli Distribution
# The binomial distribution is essentially a series of Bernoulli trials. Here’s how they relate:
#
# Single Trial vs. Multiple Trials: The Bernoulli distribution models the outcome of a single trial with two outcomes (success or failure). In contrast, the binomial distribution aggregates the outcomes of multiple Bernoulli trials (i.e.,
#
# n trials), counting the total number of successes.
#
# Parameters:
#
# A Bernoulli distribution is defined by one parameter
#
# p, the probability of success.
# A binomial distribution is defined by two parameters:
#
# n (the number of trials) and
#
# p (the probability of success in each trial).
# Formulas:
#
# The probability mass function (PMF) for a Bernoulli trial is given by:
#
# P(X=k)=p
# k
#  (1−p)
# 1−k
#  ,k∈{0,1}
# The PMF for a binomial distribution is given by:
#
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#  ,k=0,1,…,n
# Here,
#
# (
# k
# n
# ​
#  ) is the binomial coefficient, representing the number of ways to choose
#
# k successes from
#
# n trials.

# %%
# Question5: What are the key properties of the Poisson distribution, and when is it appropriate to 
# use this distribution?

# %% [markdown]
# The Poisson distribution is a probability distribution that models the number of events occurring within a fixed interval of time or space, given that these events occur with a known constant mean rate and independently of the time since the last event. Here are the key properties and conditions for using the Poisson distribution:
#
# Key Properties of the Poisson Distribution
# Discrete Distribution: The Poisson distribution is a discrete probability distribution, meaning it describes the probability of a count of events (e.g., 0, 1, 2, ...).
#
# Parameter: It is characterized by a single parameter,
#
# λ (lambda), which represents the average number of events in the given interval.
#
# Probability Mass Function (PMF):
#
#
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#
# ​
#  ,k=0,1,2,…
# This formula calculates the probability of observing
# 𝑘
# k events when the average rate is
#
# λ.
#
# Mean and Variance: Both the mean and variance of a Poisson distribution are equal to
#
# λ:
#
# Mean:
# E[X]=λ
# Variance:
# Var(X)=λ
# Memoryless Property: The Poisson process has a memoryless property, meaning the number of events in non-overlapping intervals is independent.
#
# When to Use the Poisson Distribution
# The Poisson distribution is appropriate to use under the following conditions:
#
# Rare Events: It is suitable for modeling rare events that occur infrequently within a specified time or space.
#
# Fixed Interval: The distribution is applied to count the number of events in a fixed interval (time, area, volume, etc.).
#
# Independence: The occurrence of one event does not affect the probability of another event occurring. Events are considered independent.
#
# Constant Average Rate: The events occur with a constant average rate
# 𝜆
# λ over the interval.
#
# Examples of Appropriate Use Cases
# The number of phone calls received at a call center in an hour.
# The number of decay events per unit time from a radioactive source.
# The number of emails received in a day.
# The number of accidents occurring at a traffic intersection in a month.

# %%
# Question6: Define the terms "probability distribution" and "probability density function" (PDF). 
# How does a PDF differ from a probability mass function (PMF)

# %% [markdown]
# A probability distribution is a mathematical function that describes the likelihood of different outcomes in a random experiment. It provides a way to quantify the uncertainty associated with random variables, assigning probabilities to each possible value or range of values that the variable can take.
#
# There are two main types of probability distributions:
#
# Discrete Probability Distribution: Used for discrete random variables, which can take on a countable number of values (e.g., rolling a die).
# Continuous Probability Distribution: Used for continuous random variables, which can take on an infinite number of values within a given range (e.g., measuring height).
# Probability Density Function (PDF)
# A probability density function (PDF) is a specific type of probability distribution used for continuous random variables. The PDF describes the relative likelihood of the random variable taking on a particular value.
#
# The PDF must satisfy two main conditions:
#
# The value of the PDF is non-negative for all values of the random variable.
# The integral of the PDF over the entire range of possible values equals 1:
# ∫
# −
# ∞
# ∞
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f(x)dx=1
# Unlike discrete probabilities, the probability of a continuous random variable taking on an exact value is always zero; instead, probabilities are found over intervals by integrating the PDF over that interval.
#
# Difference Between PDF and PMF
# The probability mass function (PMF) and PDF serve similar purposes but are used for different types of random variables:
#
# Type of Random Variable:
#
# PMF: Used for discrete random variables. It gives the probability that a discrete random variable is equal to a specific value.
# PDF: Used for continuous random variables. It describes the density of probability rather than specific probabilities.
# Calculation:
#
# PMF: The PMF provides the probability directly:
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑝
# (
# 𝑘
# )
# P(X=k)=p(k)
# PDF: The PDF provides the density, and probabilities must be calculated by integrating:
# 𝑃
# (
# 𝑎
# <
# 𝑋
# <
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a<X<b)=∫
# a
# b
# ​
#  f(x)dx
# Output:
#
# PMF: The output of a PMF is a probability, which ranges from 0 to 1.
# PDF: The output of a PDF can exceed 1, as it represents density. The area under the PDF curve over its range must equal 1 to represent total probability.

# %%
# Question7: Explain the Central Limit Theorem (CLT) with example.

# %% [markdown]
# The Central Limit Theorem (CLT) is a fundamental statistical principle that states that the distribution of the sample mean of a sufficiently large number of independent, identically distributed (i.i.d.) random variables will be approximately normally distributed, regardless of the original distribution of the variables. This approximation improves as the sample size increases.
#
# Key Points of the Central Limit Theorem
# Sample Size: The theorem applies when the sample size
# 𝑛
# n is sufficiently large (typically
# 𝑛
# ≥
# 30
# n≥30 is a common rule of thumb).
#
# Independence: The sampled observations must be independent of one another.
#
# Identical Distribution: The sampled observations should be drawn from the same distribution, though the specific distribution can be non-normal.
#
# Convergence to Normality: As the sample size increases, the distribution of the sample means approaches a normal distribution with mean
# 𝜇
# μ (the population mean) and standard deviation
# 𝜎
# /
# 𝑛
# σ/
# n
# ​
#   (the population standard deviation divided by the square root of the sample size).
#
# Example of the Central Limit Theorem
# Scenario: Suppose you have a population of students in a school, and their heights are not normally distributed (for example, they may be skewed). Let's say the average height (
# 𝜇
# μ) is 160 cm with a standard deviation (
# 𝜎
# σ) of 20 cm.
#
# Sampling: If you take random samples of size
# 𝑛
# =
# 5
# n=5 from this population and calculate the means, the distribution of these sample means will not be normally distributed due to the small sample size.
#
# Increasing Sample Size: If you increase the sample size to
# 𝑛
# =
# 30
# n=30 or more and repeat the process of taking random samples and calculating their means, the distribution of these sample means will start to resemble a normal distribution.
#
# Normal Approximation: After taking many samples of size
# 𝑛
# =
# 30
# n=30, you can plot the distribution of the sample means. According to the CLT, this distribution will approximate a normal distribution with:
#
# Mean =
# 𝜇
# =
# 160
# μ=160 cm
# Standard deviation =
# 𝜎
# 𝑛
# =
# 20
# 30
# ≈
# 3.65
# n
# ​
#
# σ
# ​
#  =
# 30
# ​
#
# 20
# ​
#  ≈3.65 cm
# Importance of the CLT
# Statistical Inference: The CLT justifies the use of normal distribution techniques for hypothesis testing and confidence intervals, even when the underlying data is not normally distributed.
#
# Practical Applications: It allows statisticians to make inferences about population parameters based on sample statistics, facilitating a wide range of applications in various fields like economics, medicine, and social sciences.

# %%
# Question8: Compare z-scores and t-scores. When should you use a z-score, and when should a t-score
# be applied instead?

# %% [markdown]
# Z-scores and t-scores are both standard scores that help assess how far a data point is from the mean in terms of standard deviations, but they are used in different contexts.
#
# Z-scores:
# Definition: A z-score indicates how many standard deviations an element is from the mean of the population.
# Formula:
#
# z=
# σ
# (X−μ)
# ​
#
# Where
# 𝑋
# X is the value,
# 𝜇
# μ is the population mean, and
# 𝜎
# σ is the population standard deviation.
# When to Use:
# The population standard deviation (
# 𝜎
# σ) is known.
# The sample size is large (typically
# 𝑛
# >
# 30
# n>30), allowing for the Central Limit Theorem to apply.
# Data is normally distributed.
# T-scores:
# Definition: A t-score is similar but is used when the sample size is small and the population standard deviation is unknown.
# Formula:
#
# t=
# (s/
# n
# ​
#  )
# (X−
# X
# ˉ
#  )
# ​
#
# Where
# 𝑋
# ˉ
# X
# ˉ
#   is the sample mean,
# 𝑠
# s is the sample standard deviation, and
# 𝑛
# n is the sample size.
# When to Use:
# The population standard deviation is unknown.
# The sample size is small (typically
# 𝑛
# <
# 30
# n<30).
# Data is normally distributed, or the sample is sufficiently representative of the population.

# %%
# Question9: Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample
# size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to
# reject the null hypothesis?

# Task: Write Python code to calculate the z-score and p-value for the given data.

# Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.

# %%
import scipy.stats as stats

# Given data
sample_mean = 105
population_mean = 100
standard_deviation = 15
sample_size = 25
significance_level = 0.05

# Calculate the z-score
z_score = (sample_mean - population_mean) / (standard_deviation / (sample_size ** 0.5))

# Calculate the p-value (for a one-tailed test)
p_value = 1 - stats.norm.cdf(z_score)

# Output the results
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")

# Decision based on the significance level
if p_value < significance_level:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Z-score: 1.6667
# P-value: 0.0478
# Reject the null hypothesis.

# %%
# Question10: Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python.
# Generate 1,000 samples and plot the distribution. What is the expected mean and variance?

# Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.

# Objective: Understand the properties of a binomial distribution and verify them through simulation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n_trials = 10
p_success = 0.6
n_samples = 1000

# Generate samples from a binomial distribution
samples = np.random.binomial(n_trials, p_success, n_samples)

# Calculate mean and variance
mean = np.mean(samples)
variance = np.var(samples)

# Expected mean and variance for a binomial distribution
expected_mean = n_trials * p_success
expected_variance = n_trials * p_success * (1 - p_success)

# Plot the distribution
plt.hist(samples, bins=np.arange(-0.5, n_trials + 1.5, 1), density=True, alpha=0.7, color='blue', edgecolor='black')
plt.title('Binomial Distribution (n=10, p=0.6)')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n_trials + 1))
plt.grid(axis='y')

# Show mean and variance
plt.axvline(mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean:.2f}')
plt.axvline(expected_mean, color='green', linestyle='dashed', linewidth=1, label=f'Expected Mean: {expected_mean:.2f}')
plt.axvline(variance, color='orange', linestyle='dashed', linewidth=1, label=f'Variance: {variance:.2f}')
plt.legend()

# Show the plot
plt.show()

# Output results
print(f"Simulated Mean: {mean:.2f}")
print(f"Simulated Variance: {variance:.2f}")
print(f"Expected Mean: {expected_mean:.2f}")
print(f"Expected Variance: {expected_variance:.2f}")
# Out:
# Simulated Mean: 5.95
# Simulated Variance: 2.45
# Expected Mean: 6.00
# Expected Variance: 2.40
